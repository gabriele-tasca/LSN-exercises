# %% [markdown]
# # Numerical Simulation Laboratory
#
# ## Exercise Sheet 11

# %% [markdown]
# ### Exercise 11.1
# We test the performance of the 1-neuron network given in the exercise sheet, changing the parameters of the network: the number of epochs $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$.

# %%
import numpy as np

# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 1000)
x_valid = np.random.uniform(-1, 1, 100)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
##### compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
# Out:
# WARNING:tensorflow:From /opt/intel/intelpython3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/intel/intelpython3/lib/python3.6/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=20,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 1000 samples, validate on 100 samples
# WARNING:tensorflow:From /opt/intel/intelpython3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 1000/1000 [==============================] - 0s 105us/sample - loss: 5.2171 - mean_squared_error: 5.2171 - val_loss: 4.8603 - val_mean_squared_error: 4.8603
# Epoch 2/20
# 1000/1000 [==============================] - 0s 24us/sample - loss: 3.5208 - mean_squared_error: 3.5208 - val_loss: 3.4492 - val_mean_squared_error: 3.4492
# Epoch 3/20
# 1000/1000 [==============================] - 0s 26us/sample - loss: 2.5680 - mean_squared_error: 2.5680 - val_loss: 2.5811 - val_mean_squared_error: 2.5811
# Epoch 4/20
# 1000/1000 [==============================] - 0s 27us/sample - loss: 1.9930 - mean_squared_error: 1.9930 - val_loss: 2.0086 - val_mean_squared_error: 2.0086
# Epoch 5/20
# 1000/1000 [==============================] - 0s 27us/sample - loss: 1.6223 - mean_squared_error: 1.6223 - val_loss: 1.6359 - val_mean_squared_error: 1.6359
# Epoch 6/20
# 1000/1000 [==============================] - 0s 29us/sample - loss: 1.3881 - mean_squared_error: 1.3881 - val_loss: 1.3710 - val_mean_squared_error: 1.3710
# Epoch 7/20
# 1000/1000 [==============================] - 0s 27us/sample - loss: 1.2270 - mean_squared_error: 1.2270 - val_loss: 1.2043 - val_mean_squared_error: 1.2043
# Epoch 8/20
# 1000/1000 [==============================] - 0s 24us/sample - loss: 1.1295 - mean_squared_error: 1.1295 - val_loss: 1.0907 - val_mean_squared_error: 1.0907
# Epoch 9/20
# 1000/1000 [==============================] - 0s 24us/sample - loss: 1.0661 - mean_squared_error: 1.0661 - val_loss: 1.0152 - val_mean_squared_error: 1.0152
# Epoch 10/20
# 1000/1000 [==============================] - 0s 23us/sample - loss: 1.0263 - mean_squared_error: 1.0263 - val_loss: 0.9606 - val_mean_squared_error: 0.9606
# Epoch 11/20
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.9992 - mean_squared_error: 0.9992 - val_loss: 0.9206 - val_mean_squared_error: 0.9206
# Epoch 12/20
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.9803 - mean_squared_error: 0.9803 - val_loss: 0.8940 - val_mean_squared_error: 0.8940
# Epoch 13/20
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.9691 - mean_squared_error: 0.9691 - val_loss: 0.8746 - val_mean_squared_error: 0.8746
# Epoch 14/20
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.9617 - mean_squared_error: 0.9617 - val_loss: 0.8609 - val_mean_squared_error: 0.8609
# Epoch 15/20
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.9570 - mean_squared_error: 0.9570 - val_loss: 0.8489 - val_mean_squared_error: 0.8489
# Epoch 16/20
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.9534 - mean_squared_error: 0.9534 - val_loss: 0.8419 - val_mean_squared_error: 0.8419
# Epoch 17/20
# 1000/1000 [==============================] - 0s 26us/sample - loss: 0.9513 - mean_squared_error: 0.9513 - val_loss: 0.8370 - val_mean_squared_error: 0.8370
# Epoch 18/20
# 1000/1000 [==============================] - 0s 27us/sample - loss: 0.9500 - mean_squared_error: 0.9500 - val_loss: 0.8330 - val_mean_squared_error: 0.8330
# Epoch 19/20
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.9495 - mean_squared_error: 0.9495 - val_loss: 0.8307 - val_mean_squared_error: 0.8307
# Epoch 20/20
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.9492 - mean_squared_error: 0.9492 - val_loss: 0.8286 - val_mean_squared_error: 0.8286

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test mean square error:', score[1])
# Out:
# 100/100 [==============================] - 0s 27us/sample - loss: 0.8286 - mean_squared_error: 0.8286
#
# Test loss: 0.8286302137374878
# Test mean square error: 0.8286302

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# As it appears, the network can work well even with very noisy data, and with relatively few epochs, provided it has a reasonable amount of data for training.

# %% [markdown]
# ### Exercise 11.2
# We try to extend our neural network to fit a 3rd-order polynomial:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
#
# We experiment with different network layouts and compare the quality and efficiency of the results.

# %%
#generate data
import numpy as np

def f(x):
    return 4 - 3*x - 2*x**2 + 3*x**3

np.random.seed(0)
x_train = np.random.uniform(-1, 1, 10000)
x_valid = np.random.uniform(-1, 1, 1000)
x_valid.sort()
y_target = f(x_valid)

sigma = 0.1 # noise standard deviation
y_train = np.random.normal(f(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(f(x_valid), sigma)

# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
##### compose the NN model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

# %% [markdown]
# We start from a very basic network, with a single Relu layer of 5 neurons and a single final neuron, with no activation function, to collect the results and yield the predicted value of $f(x)$.

# %%
model1 = tf.keras.Sequential()
model1.add(Dense(5, input_shape=(1,), activation='relu'  ) )
model1.add(Dense(1))
# compile the model choosing optimizer, loss and metrics objects
model1.compile(optimizer='sgd', loss='mse', metrics=['mse'])
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                  min_delta=0, patience=100, mode='auto')

history = model1.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid) )
# Out:
# Train on 10000 samples, validate on 1000 samples
# Epoch 1/30
# 10000/10000 [==============================] - 0s 29us/sample - loss: 0.8689 - mean_squared_error: 0.8689 - val_loss: 0.4794 - val_mean_squared_error: 0.4794
# Epoch 2/30
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.4186 - mean_squared_error: 0.4186 - val_loss: 0.3639 - val_mean_squared_error: 0.3639
# Epoch 3/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.3091 - mean_squared_error: 0.3091 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 4/30
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.1891 - val_mean_squared_error: 0.1891
# Epoch 5/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.1645 - mean_squared_error: 0.1645 - val_loss: 0.1423 - val_mean_squared_error: 0.1423
# Epoch 6/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.1266 - mean_squared_error: 0.1266 - val_loss: 0.1108 - val_mean_squared_error: 0.1108
# Epoch 7/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.1017 - mean_squared_error: 0.1017 - val_loss: 0.0902 - val_mean_squared_error: 0.0902
# Epoch 8/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0854 - mean_squared_error: 0.0854 - val_loss: 0.0755 - val_mean_squared_error: 0.0755
# Epoch 9/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0740 - mean_squared_error: 0.0740 - val_loss: 0.0675 - val_mean_squared_error: 0.0675
# Epoch 10/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0664 - mean_squared_error: 0.0664 - val_loss: 0.0617 - val_mean_squared_error: 0.0617
# Epoch 11/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0610 - mean_squared_error: 0.0610 - val_loss: 0.0562 - val_mean_squared_error: 0.0562
# Epoch 12/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0569 - mean_squared_error: 0.0569 - val_loss: 0.0531 - val_mean_squared_error: 0.0531
# Epoch 13/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0537 - mean_squared_error: 0.0537 - val_loss: 0.0505 - val_mean_squared_error: 0.0505
# Epoch 14/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0510 - mean_squared_error: 0.0510 - val_loss: 0.0476 - val_mean_squared_error: 0.0476
# Epoch 15/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0487 - mean_squared_error: 0.0487 - val_loss: 0.0460 - val_mean_squared_error: 0.0460
# Epoch 16/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0468 - mean_squared_error: 0.0468 - val_loss: 0.0439 - val_mean_squared_error: 0.0439
# Epoch 17/30
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.0450 - mean_squared_error: 0.0450 - val_loss: 0.0423 - val_mean_squared_error: 0.0423
# Epoch 18/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0439 - mean_squared_error: 0.0439 - val_loss: 0.0417 - val_mean_squared_error: 0.0417
# Epoch 19/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0428 - mean_squared_error: 0.0428 - val_loss: 0.0415 - val_mean_squared_error: 0.0415
# Epoch 20/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0419 - mean_squared_error: 0.0419 - val_loss: 0.0397 - val_mean_squared_error: 0.0397
# Epoch 21/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0412 - mean_squared_error: 0.0412 - val_loss: 0.0405 - val_mean_squared_error: 0.0405
# Epoch 22/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0407 - mean_squared_error: 0.0407 - val_loss: 0.0394 - val_mean_squared_error: 0.0394
# Epoch 23/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.0384 - val_mean_squared_error: 0.0384
# Epoch 24/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0394 - mean_squared_error: 0.0394 - val_loss: 0.0374 - val_mean_squared_error: 0.0374
# Epoch 25/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0377 - val_mean_squared_error: 0.0377
# Epoch 26/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0385 - mean_squared_error: 0.0385 - val_loss: 0.0368 - val_mean_squared_error: 0.0368
# Epoch 27/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 0.0379 - val_mean_squared_error: 0.0379
# Epoch 28/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0381 - mean_squared_error: 0.0381 - val_loss: 0.0365 - val_mean_squared_error: 0.0365
# Epoch 29/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0377 - mean_squared_error: 0.0377 - val_loss: 0.0356 - val_mean_squared_error: 0.0356
# Epoch 30/30
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0353 - val_mean_squared_error: 0.0353

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()
x_predicted = np.random.uniform(-1, 1, 1000)
y_predicted = model1.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# The fit is rather poor. A single relu layer appears to not be able to capture the nonlinearity of the function. We switch to an intrinsically nonlinear activation function.

# %%
model2 = tf.keras.Sequential()
model2.add(Dense(5, input_shape=(1,), activation='tanh'  ) )
model2.add(Dense(1))

model2.compile(optimizer='sgd', loss='mse', metrics=['mse'])
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                  min_delta=0, patience=100, mode='auto')

history = model2.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=20,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid) )
# Out:
# Train on 10000 samples, validate on 1000 samples
# Epoch 1/20
# 10000/10000 [==============================] - 0s 31us/sample - loss: 0.9643 - mean_squared_error: 0.9643 - val_loss: 0.4406 - val_mean_squared_error: 0.4406
# Epoch 2/20
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.3961 - mean_squared_error: 0.3961 - val_loss: 0.3579 - val_mean_squared_error: 0.3579
# Epoch 3/20
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.3135 - mean_squared_error: 0.3135 - val_loss: 0.2769 - val_mean_squared_error: 0.2769
# Epoch 4/20
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.2402 - mean_squared_error: 0.2402 - val_loss: 0.2067 - val_mean_squared_error: 0.2067
# Epoch 5/20
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.1737 - mean_squared_error: 0.1737 - val_loss: 0.1444 - val_mean_squared_error: 0.1444
# Epoch 6/20
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.1187 - mean_squared_error: 0.1187 - val_loss: 0.0959 - val_mean_squared_error: 0.0959
# Epoch 7/20
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0827 - mean_squared_error: 0.0827 - val_loss: 0.0680 - val_mean_squared_error: 0.0680
# Epoch 8/20
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.0614 - mean_squared_error: 0.0614 - val_loss: 0.0518 - val_mean_squared_error: 0.0518
# Epoch 9/20
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0425 - val_mean_squared_error: 0.0425
# Epoch 10/20
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.0418 - mean_squared_error: 0.0418 - val_loss: 0.0373 - val_mean_squared_error: 0.0373
# Epoch 11/20
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 12/20
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0306 - val_mean_squared_error: 0.0306
# Epoch 13/20
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0315 - mean_squared_error: 0.0315 - val_loss: 0.0286 - val_mean_squared_error: 0.0286
# Epoch 14/20
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 15/20
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 16/20
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0264 - mean_squared_error: 0.0264 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 17/20
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 18/20
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 19/20
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 20/20
# 10000/10000 [==============================] - 0s 21us/sample - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0207 - val_mean_squared_error: 0.0207

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()
x_predicted = np.random.uniform(-1, 1, 1000)
y_predicted = model2.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# Although the quality of the fit is still not great, the tanh activation seems to work in giving the curve a smoother shape.

# %%
model3 = tf.keras.Sequential()
model3.add(Dense(5, input_shape=(1,), activation='tanh'  ) )
model3.add(Dense(5, activation='tanh'))
model3.add(Dense(1))

model3.compile(optimizer='sgd', loss='mse', metrics=['mse'])
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                  min_delta=0, patience=100, mode='auto')

history = model3.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=20,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid) )
# Out:
# Train on 10000 samples, validate on 1000 samples
# Epoch 1/20
# 10000/10000 [==============================] - 0s 34us/sample - loss: 0.6342 - mean_squared_error: 0.6342 - val_loss: 0.1829 - val_mean_squared_error: 0.1829
# Epoch 2/20
# 10000/10000 [==============================] - 0s 24us/sample - loss: 0.1101 - mean_squared_error: 0.1101 - val_loss: 0.0664 - val_mean_squared_error: 0.0664
# Epoch 3/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0511 - mean_squared_error: 0.0511 - val_loss: 0.0378 - val_mean_squared_error: 0.0378
# Epoch 4/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0293 - val_mean_squared_error: 0.0293
# Epoch 5/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 6/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 7/20
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 8/20
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 9/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 10/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 11/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 12/20
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 13/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 14/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0152 - val_mean_squared_error: 0.0152
# Epoch 15/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 16/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 17/20
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 18/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 19/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 20/20
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0139 - val_mean_squared_error: 0.0139

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()
x_predicted = np.random.uniform(-1, 1, 1000)
y_predicted = model3.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# At this point, it seems that just adding more tanh layers is a good way to progressively improve the quality of the fit.

# %%
model4 = tf.keras.Sequential()
model4.add(Dense(7, input_shape=(1,), activation='tanh'  ) )
model4.add(Dense(7, activation='tanh'))
model4.add(Dense(7, activation='tanh'))
model4.add(Dense(1))

model4.compile(optimizer='sgd', loss='mse', metrics=['mse'])
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                  min_delta=0, patience=100, mode='auto')

history = model3.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=80,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid) )
# Out:
# Train on 10000 samples, validate on 1000 samples
# Epoch 1/80
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 2/80
# 10000/10000 [==============================] - 0s 24us/sample - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 3/80
# 10000/10000 [==============================] - 0s 24us/sample - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 4/80
# 10000/10000 [==============================] - 0s 24us/sample - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 5/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 6/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0130 - val_mean_squared_error: 0.0130
# Epoch 7/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 8/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 9/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 10/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# Epoch 11/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 12/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 13/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 14/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 15/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 16/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 17/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 18/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 19/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 20/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 21/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 22/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 23/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 24/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 25/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 26/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 27/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 28/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 29/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 30/80
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 31/80
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 32/80
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 33/80
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 34/80
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 35/80
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 36/80
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 37/80
# 10000/10000 [==============================] - 0s 22us/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 38/80
# 10000/10000 [==============================] - 0s 24us/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 39/80
# 10000/10000 [==============================] - 0s 47us/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 40/80
# 10000/10000 [==============================] - 1s 53us/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 41/80
# 10000/10000 [==============================] - 0s 37us/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 42/80
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 43/80
# 10000/10000 [==============================] - 0s 24us/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 44/80
# 10000/10000 [==============================] - 0s 24us/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 45/80
# 10000/10000 [==============================] - 0s 25us/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 46/80
# 10000/10000 [==============================] - 0s 41us/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 47/80
# 10000/10000 [==============================] - 0s 44us/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 48/80
# 10000/10000 [==============================] - 0s 48us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 49/80
# 10000/10000 [==============================] - 0s 37us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 50/80
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 51/80
# 10000/10000 [==============================] - 0s 24us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 52/80
# 10000/10000 [==============================] - 0s 24us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 53/80
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 54/80
# 10000/10000 [==============================] - 0s 45us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 55/80
# 10000/10000 [==============================] - 0s 48us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 56/80
# 10000/10000 [==============================] - 0s 44us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 57/80
# 10000/10000 [==============================] - 0s 43us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 58/80
# 10000/10000 [==============================] - 0s 31us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 59/80
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 60/80
# 10000/10000 [==============================] - 0s 23us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 61/80
# 10000/10000 [==============================] - 0s 45us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 62/80
# 10000/10000 [==============================] - 1s 53us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 63/80
# 10000/10000 [==============================] - 1s 57us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 64/80
# 10000/10000 [==============================] - 0s 35us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 65/80
# 10000/10000 [==============================] - 0s 30us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 66/80
# 10000/10000 [==============================] - 0s 24us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 67/80
# 10000/10000 [==============================] - 0s 36us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 68/80
# 10000/10000 [==============================] - 1s 54us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 69/80
# 10000/10000 [==============================] - 0s 48us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 70/80
# 10000/10000 [==============================] - 0s 42us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 71/80
# 10000/10000 [==============================] - 0s 32us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 72/80
# 10000/10000 [==============================] - 1s 55us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 73/80
# 10000/10000 [==============================] - 0s 48us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 74/80
# 10000/10000 [==============================] - 0s 44us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 75/80
# 10000/10000 [==============================] - 0s 47us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 76/80
# 10000/10000 [==============================] - 0s 46us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 77/80
# 10000/10000 [==============================] - 0s 47us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 78/80
# 10000/10000 [==============================] - 0s 33us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 79/80
# 10000/10000 [==============================] - 1s 53us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 80/80
# 10000/10000 [==============================] - 0s 44us/sample - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0115 - val_mean_squared_error: 0.0115

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()
x_predicted = np.random.uniform(-1, 1, 1000)
y_predicted = model3.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# As the number of layers increases, the fit keeps getting noticeably better, but the efficiency lowers, not only because each epoch requires more calculations due to the increased number of nodes, but also because the network needs more epochs to fully train. In the example above, the loss is still steadily decreasing after 80 epochs, although it is already much lower than in all other models previously tested.
#
# The final rise of the function just before the end of the explored intervals still proves very hard to model, for reasons we do not understand at all. This is enough to suggest that the model probably won't work very well on points outside of the $x$ interval it has been trained on. We try using the last model for prediction on an extended interval:

# %%
edge = 1.3
x_predicted = np.random.uniform(-edge, edge, 1000)
x_flat = np.arange(-edge, edge, 0.1)
y_predicted = model3.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
y_flat = f(x_flat)
plt.plot(x_flat, y_flat)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# As expected, the model has a completely different idea of how the function should look like. Even from a more classical function fitting perspective this is not surprising, because we know that a finite number of points can always be interpolated by different functions that become arbitrarily different when we get farther from the original points, unless we restrict the fitting model to a functional form that is already similar to the one underlying the data. Since our neural network receives no extra information about the true functional form, in this case it becomes impossible for it to generalize.

# %% [markdown]
# ### Exercise 11.3
# We try to use the Neural Network model to fit a more complicated 2D function:
#
# $f(x,y) = \sin(x^2+y^2)$

# %%
#generate data
import numpy as np

def f(x,y):
    return np.sin( x**2 + y**2)

np.random.seed(0)
x_train = np.random.uniform(-1.5, 1.5, 10000)
x_valid = np.random.uniform(-1.5, 1.5, 1000)
y_train = np.random.uniform(-1.5, 1.5, 10000)
y_valid = np.random.uniform(-1.5, 1.5, 1000)
f_target = f(x_valid,y_valid)
in_valid = np.c_[x_valid, y_valid]
in_train = np.c_[x_train, y_train]

y_range = np.arange(-1.5, 1.5, 0.1)
x_range = np.arange(-1.5, 1.5, 0.1)
x_range, y_range = np.meshgrid(x_range, y_range)
f_range = f(x_range, y_range)


sigma = 0.03 # noise standard deviation, for the moment it is absent
f_train = np.random.normal(f(x_train, y_train), sigma) # actual measures from which we want to guess regression parameters
f_valid = np.random.normal(f(x_valid, y_valid), sigma)

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x_train, y_train, f_train, c=f_train, marker='.')
ax.plot_wireframe(x_range, y_range, f_range, color='red' )
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# ax.view_init(10, 30)
plt.show()


# # plot training and target dataset
# plt.plot(x_valid, y_target)
# plt.scatter(x_valid, y_valid, color='r')
# plt.grid(True); plt.show()

# %%
##### compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(7, input_shape=(2,), activation='tanh'  ) )
model.add(Dense(7, activation='tanh')   )
model.add(Dense(7, activation='relu')   )
model.add(Dense(7, activation='tanh')   )
model.add(Dense(1 ))

model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                  min_delta=0, patience=100, mode='auto')

history = model.fit(x=in_train, y=f_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(in_valid,f_valid) )
# Out:
# Train on 10000 samples, validate on 1000 samples
# Epoch 1/100
# 10000/10000 [==============================] - 1s 75us/sample - loss: 0.1635 - mean_squared_error: 0.1635 - val_loss: 0.1445 - val_mean_squared_error: 0.1445
# Epoch 2/100
# 10000/10000 [==============================] - 1s 56us/sample - loss: 0.1457 - mean_squared_error: 0.1457 - val_loss: 0.1405 - val_mean_squared_error: 0.1405
# Epoch 3/100
# 10000/10000 [==============================] - 0s 45us/sample - loss: 0.1431 - mean_squared_error: 0.1431 - val_loss: 0.1375 - val_mean_squared_error: 0.1375
# Epoch 4/100
# 10000/10000 [==============================] - 1s 54us/sample - loss: 0.1404 - mean_squared_error: 0.1404 - val_loss: 0.1355 - val_mean_squared_error: 0.1355
# Epoch 5/100
# 10000/10000 [==============================] - 1s 50us/sample - loss: 0.1376 - mean_squared_error: 0.1376 - val_loss: 0.1316 - val_mean_squared_error: 0.1316
# Epoch 6/100
# 10000/10000 [==============================] - 1s 55us/sample - loss: 0.1346 - mean_squared_error: 0.1346 - val_loss: 0.1280 - val_mean_squared_error: 0.1280
# Epoch 7/100
# 10000/10000 [==============================] - 0s 46us/sample - loss: 0.1309 - mean_squared_error: 0.1309 - val_loss: 0.1241 - val_mean_squared_error: 0.1241
# Epoch 8/100
# 10000/10000 [==============================] - 1s 55us/sample - loss: 0.1266 - mean_squared_error: 0.1266 - val_loss: 0.1195 - val_mean_squared_error: 0.1195
# Epoch 9/100
# 10000/10000 [==============================] - 0s 33us/sample - loss: 0.1225 - mean_squared_error: 0.1225 - val_loss: 0.1157 - val_mean_squared_error: 0.1157
# Epoch 10/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.1190 - mean_squared_error: 0.1190 - val_loss: 0.1116 - val_mean_squared_error: 0.1116
# Epoch 11/100
# 10000/10000 [==============================] - 0s 46us/sample - loss: 0.1156 - mean_squared_error: 0.1156 - val_loss: 0.1086 - val_mean_squared_error: 0.1086
# Epoch 12/100
# 10000/10000 [==============================] - 0s 45us/sample - loss: 0.1123 - mean_squared_error: 0.1123 - val_loss: 0.1052 - val_mean_squared_error: 0.1052
# Epoch 13/100
# 10000/10000 [==============================] - 0s 45us/sample - loss: 0.1093 - mean_squared_error: 0.1093 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 14/100
# 10000/10000 [==============================] - 0s 29us/sample - loss: 0.1065 - mean_squared_error: 0.1065 - val_loss: 0.0999 - val_mean_squared_error: 0.0999
# Epoch 15/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.0972 - val_mean_squared_error: 0.0972
# Epoch 16/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.1015 - mean_squared_error: 0.1015 - val_loss: 0.0951 - val_mean_squared_error: 0.0951
# Epoch 17/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0990 - mean_squared_error: 0.0990 - val_loss: 0.0937 - val_mean_squared_error: 0.0937
# Epoch 18/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0964 - mean_squared_error: 0.0964 - val_loss: 0.0904 - val_mean_squared_error: 0.0904
# Epoch 19/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0931 - mean_squared_error: 0.0931 - val_loss: 0.0881 - val_mean_squared_error: 0.0881
# Epoch 20/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0895 - mean_squared_error: 0.0895 - val_loss: 0.0836 - val_mean_squared_error: 0.0836
# Epoch 21/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0852 - mean_squared_error: 0.0852 - val_loss: 0.0794 - val_mean_squared_error: 0.0794
# Epoch 22/100
# 10000/10000 [==============================] - 0s 25us/sample - loss: 0.0802 - mean_squared_error: 0.0802 - val_loss: 0.0747 - val_mean_squared_error: 0.0747
# Epoch 23/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0741 - mean_squared_error: 0.0741 - val_loss: 0.0745 - val_mean_squared_error: 0.0745
# Epoch 24/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0685 - mean_squared_error: 0.0685 - val_loss: 0.0641 - val_mean_squared_error: 0.0641
# Epoch 25/100
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.0626 - mean_squared_error: 0.0626 - val_loss: 0.0585 - val_mean_squared_error: 0.0585
# Epoch 26/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0576 - mean_squared_error: 0.0576 - val_loss: 0.0538 - val_mean_squared_error: 0.0538
# Epoch 27/100
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.0534 - mean_squared_error: 0.0534 - val_loss: 0.0507 - val_mean_squared_error: 0.0507
# Epoch 28/100
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.0505 - mean_squared_error: 0.0505 - val_loss: 0.0522 - val_mean_squared_error: 0.0522
# Epoch 29/100
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.0480 - mean_squared_error: 0.0480 - val_loss: 0.0454 - val_mean_squared_error: 0.0454
# Epoch 30/100
# 10000/10000 [==============================] - 0s 30us/sample - loss: 0.0458 - mean_squared_error: 0.0458 - val_loss: 0.0437 - val_mean_squared_error: 0.0437
# Epoch 31/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0438 - mean_squared_error: 0.0438 - val_loss: 0.0439 - val_mean_squared_error: 0.0439
# Epoch 32/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0419 - mean_squared_error: 0.0419 - val_loss: 0.0395 - val_mean_squared_error: 0.0395
# Epoch 33/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0397 - mean_squared_error: 0.0397 - val_loss: 0.0389 - val_mean_squared_error: 0.0389
# Epoch 34/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.0356 - val_mean_squared_error: 0.0356
# Epoch 35/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 36/100
# 10000/10000 [==============================] - 0s 30us/sample - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.0340 - val_mean_squared_error: 0.0340
# Epoch 37/100
# 10000/10000 [==============================] - 0s 29us/sample - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.0289 - val_mean_squared_error: 0.0289
# Epoch 38/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 39/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 40/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 41/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 42/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 43/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 44/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 45/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 46/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 47/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 48/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 49/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 50/100
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 51/100
# 10000/10000 [==============================] - 0s 29us/sample - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 52/100
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 53/100
# 10000/10000 [==============================] - 0s 29us/sample - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 54/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 55/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 56/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 57/100
# 10000/10000 [==============================] - 0s 29us/sample - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 58/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 59/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 60/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 61/100
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 62/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 63/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 64/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 65/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 66/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 67/100
# 10000/10000 [==============================] - 0s 36us/sample - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 68/100
# 10000/10000 [==============================] - 0s 29us/sample - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 69/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 70/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 71/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 72/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 73/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 74/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 75/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 76/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 77/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 78/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 79/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 80/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 81/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 82/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 83/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 84/100
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 85/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 86/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 87/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 88/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 89/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 90/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 91/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 92/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 93/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 94/100
# 10000/10000 [==============================] - 0s 27us/sample - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 95/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 96/100
# 10000/10000 [==============================] - 0s 29us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 97/100
# 10000/10000 [==============================] - 0s 30us/sample - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 98/100
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 99/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 100/100
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0029 - val_mean_squared_error: 0.0029

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
npoints = 2000
edge = 1.55
in_predicted = np.c_[np.random.uniform(-edge, edge, npoints), np.random.uniform(-edge, edge, npoints)]
f_predicted = model.predict(in_predicted)
ax.scatter(in_predicted[:,0], in_predicted[:,1], f_predicted, cmap=matplotlib.cm.coolwarm, marker='.')
ax.plot_wireframe(x_range, y_range, f_range, color='red' )
plt.show()

# %% [markdown]
# As expected, the problem is considerably harder than before, and it seems that there is little hope of obtaining a reasonably good fit without at least two or three intermediate layers and a good number of epochs.
