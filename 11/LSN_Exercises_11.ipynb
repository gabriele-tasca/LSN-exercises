# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> Python Exercise 11 </span>
# ## <span style="color:orange"> Keras - Neural Network regression </span>

# %% [markdown]
# ### Overview
#
# In this notebook our task will be to perform machine learning regression on noisy data with a Neural Network (NN).
#
# We will explore how the ability to fit depends on the structure of the NN. The goal is also to build intuition about why prediction is difficult.

# %% [markdown]
# ### The Prediction Problem
#
# Consider a probabilistic process that gives rise to labeled data $(x,y)$. The data is generated by drawing samples from the equation
#
# $$
#     y_i= f(x_i) + \eta_i,
# $$
#
# where $f(x_i)$ is some fixed, but (possibly unknown) function, and $\eta_i$ is a Gaussian, uncorrelate noise variable such that
#
# $$
# \langle \eta_i \rangle=0 \\
# \langle \eta_i \eta_j \rangle = \delta_{ij} \sigma
# $$
#
# We will refer to the $f(x_i)$ as the **true features** used to generate the data.
#
# To make prediction, we will consider a NN that depend on its parameters, weights and biases. The functions that the NN can model respresent the **model class** that we are using to try to model the data and make predictions.
#
# To learn the parameters of the NN, we will train our models on a **training data set** and then test the effectiveness of the NN on a *different* dataset, the **validation data set**. The reason we must divide our data into a training and test dataset is that the point of machine learning is to make accurate predictions about new data we have not seen.
#
# To measure our ability to predict, we will learn our parameters by fitting our training dataset and then making predictions on our test data set. One common measure of predictive  performance of our algorithm is to compare the predictions,$\{y_j^\mathrm{pred}\}$, to the true values $\{y_j\}$. A commonly employed measure for this is the sum of the mean square-error (MSE) on the test set:
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$
#
# We will try to get a qualitative picture by examining plots on validation and training data.

# %% [markdown]
# ### Linear fit
#
# We start by considering the very simple case:
# $$
# f(x)=2x+1
# $$

# %% [markdown]
# Let's start defining the parameters of an ideal linear function which we are going to predict through a neural network regression

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# Now let's generate a set of input data which will slightly deviate from our ideal behaviour using a random noise (that actually is set to zero):

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 100)
x_valid = np.random.uniform(-1, 1, 10)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.0 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %% [markdown]
# If you remember how a single node of a neural network works, you can easily spot that **just a single neuron can make the job**. So let's start using a simple Sequential model with just one layer on one neuron only!

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
# Out:
# WARNING:tensorflow:From /opt/intel/intelpython3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/intel/intelpython3/lib/python3.6/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
# get a summary of our composed model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 100 samples, validate on 10 samples
# WARNING:tensorflow:From /opt/intel/intelpython3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
# 100/100 [==============================] - 0s 2ms/sample - loss: 3.8506 - mean_squared_error: 3.8506 - val_loss: 4.4509 - val_mean_squared_error: 4.4509
# Epoch 2/30
# 100/100 [==============================] - 0s 151us/sample - loss: 3.6016 - mean_squared_error: 3.6016 - val_loss: 4.0475 - val_mean_squared_error: 4.0475
# Epoch 3/30
# 100/100 [==============================] - 0s 135us/sample - loss: 3.3214 - mean_squared_error: 3.3214 - val_loss: 3.7660 - val_mean_squared_error: 3.7660
# Epoch 4/30
# 100/100 [==============================] - 0s 118us/sample - loss: 3.1187 - mean_squared_error: 3.1187 - val_loss: 3.4557 - val_mean_squared_error: 3.4557
# Epoch 5/30
# 100/100 [==============================] - 0s 126us/sample - loss: 2.8994 - mean_squared_error: 2.8994 - val_loss: 3.2626 - val_mean_squared_error: 3.2626
# Epoch 6/30
# 100/100 [==============================] - 0s 122us/sample - loss: 2.7466 - mean_squared_error: 2.7466 - val_loss: 3.0413 - val_mean_squared_error: 3.0413
# Epoch 7/30
# 100/100 [==============================] - 0s 115us/sample - loss: 2.5865 - mean_squared_error: 2.5865 - val_loss: 2.8416 - val_mean_squared_error: 2.8416
# Epoch 8/30
# 100/100 [==============================] - 0s 106us/sample - loss: 2.4332 - mean_squared_error: 2.4332 - val_loss: 2.6492 - val_mean_squared_error: 2.6492
# Epoch 9/30
# 100/100 [==============================] - 0s 141us/sample - loss: 2.2874 - mean_squared_error: 2.2874 - val_loss: 2.4703 - val_mean_squared_error: 2.4703
# Epoch 10/30
# 100/100 [==============================] - 0s 119us/sample - loss: 2.1516 - mean_squared_error: 2.1516 - val_loss: 2.3091 - val_mean_squared_error: 2.3091
# Epoch 11/30
# 100/100 [==============================] - 0s 127us/sample - loss: 2.0297 - mean_squared_error: 2.0297 - val_loss: 2.1888 - val_mean_squared_error: 2.1888
# Epoch 12/30
# 100/100 [==============================] - 0s 108us/sample - loss: 1.9306 - mean_squared_error: 1.9306 - val_loss: 2.0320 - val_mean_squared_error: 2.0320
# Epoch 13/30
# 100/100 [==============================] - 0s 114us/sample - loss: 1.8076 - mean_squared_error: 1.8076 - val_loss: 1.9057 - val_mean_squared_error: 1.9057
# Epoch 14/30
# 100/100 [==============================] - 0s 110us/sample - loss: 1.7077 - mean_squared_error: 1.7077 - val_loss: 1.7227 - val_mean_squared_error: 1.7227
# Epoch 15/30
# 100/100 [==============================] - 0s 114us/sample - loss: 1.5741 - mean_squared_error: 1.5741 - val_loss: 1.6121 - val_mean_squared_error: 1.6121
# Epoch 16/30
# 100/100 [==============================] - 0s 115us/sample - loss: 1.4855 - mean_squared_error: 1.4855 - val_loss: 1.5325 - val_mean_squared_error: 1.5325
# Epoch 17/30
# 100/100 [==============================] - 0s 105us/sample - loss: 1.4140 - mean_squared_error: 1.4140 - val_loss: 1.4365 - val_mean_squared_error: 1.4365
# Epoch 18/30
# 100/100 [==============================] - ETA: 0s - loss: 1.3516 - mean_squared_error: 1.35 - 0s 107us/sample - loss: 1.3354 - mean_squared_error: 1.3354 - val_loss: 1.3341 - val_mean_squared_error: 1.3341
# Epoch 19/30
# 100/100 [==============================] - 0s 122us/sample - loss: 1.2576 - mean_squared_error: 1.2576 - val_loss: 1.2594 - val_mean_squared_error: 1.2594
# Epoch 20/30
# 100/100 [==============================] - 0s 133us/sample - loss: 1.1956 - mean_squared_error: 1.1956 - val_loss: 1.1885 - val_mean_squared_error: 1.1885
# Epoch 21/30
# 100/100 [==============================] - 0s 110us/sample - loss: 1.1256 - mean_squared_error: 1.1256 - val_loss: 1.1311 - val_mean_squared_error: 1.1311
# Epoch 22/30
# 100/100 [==============================] - 0s 127us/sample - loss: 1.0728 - mean_squared_error: 1.0728 - val_loss: 1.0524 - val_mean_squared_error: 1.0524
# Epoch 23/30
# 100/100 [==============================] - ETA: 0s - loss: 1.1377 - mean_squared_error: 1.13 - 0s 112us/sample - loss: 1.0085 - mean_squared_error: 1.0085 - val_loss: 1.0050 - val_mean_squared_error: 1.0050
# Epoch 24/30
# 100/100 [==============================] - 0s 115us/sample - loss: 0.9639 - mean_squared_error: 0.9639 - val_loss: 0.9560 - val_mean_squared_error: 0.9560
# Epoch 25/30
# 100/100 [==============================] - 0s 122us/sample - loss: 0.9148 - mean_squared_error: 0.9148 - val_loss: 0.8864 - val_mean_squared_error: 0.8864
# Epoch 26/30
# 100/100 [==============================] - 0s 127us/sample - loss: 0.8578 - mean_squared_error: 0.8578 - val_loss: 0.8396 - val_mean_squared_error: 0.8396
# Epoch 27/30
# 100/100 [==============================] - 0s 122us/sample - loss: 0.8083 - mean_squared_error: 0.8083 - val_loss: 0.7964 - val_mean_squared_error: 0.7964
# Epoch 28/30
# 100/100 [==============================] - 0s 97us/sample - loss: 0.7676 - mean_squared_error: 0.7676 - val_loss: 0.7539 - val_mean_squared_error: 0.7539
# Epoch 29/30
# 100/100 [==============================] - 0s 111us/sample - loss: 0.7282 - mean_squared_error: 0.7282 - val_loss: 0.7043 - val_mean_squared_error: 0.7043
# Epoch 30/30
# 100/100 [==============================] - 0s 103us/sample - loss: 0.6838 - mean_squared_error: 0.6838 - val_loss: 0.6758 - val_mean_squared_error: 0.6758

# %%
# return weights
model.get_weights()
# Out:
# [array([[0.6055087]], dtype=float32), array([0.8153647], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 10/10 [==============================] - 0s 102us/sample - loss: 0.6758 - mean_squared_error: 0.6758
#
# Test loss: 0.6758185625076294
# Test accuracy: 0.67581856

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 10/10 [==============================] - 0s 90us/sample - loss: 0.6758 - mean_squared_error: 0.6758
#
# Test loss: 0.6758185625076294
# Test accuracy: 0.67581856

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# In order to make practice with NN, explore reasonable different choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Make graphs comparing fits for different NNs.
# Check your NN models by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>

# %% [markdown]
# ### <span style="color:green">Supplementary material: Keras model.fit available callbacks</span>

# %% [markdown]
# The .fit method can also get <a href=https://keras.io/callbacks/>callback</a> functions which can be used to customize the fitting procedure with special actions.
#
# Keras provides some predefined callbacks to feed in, among them for example:
# - **TerminateOnNaN()**: that terminates training when a NaN loss is encountered
# - **ModelCheckpoint(filepath)**: that save the model after every epoch
# - **EarlyStopping()**: which stop training when a monitored quantity has stopped improving
#
# You can select one or more callback and pass them as a list to the callback argument of the fit method.

# %% [markdown]
# Now we are going to construct a callback object to represent how estimated parameters are converging during the training procedure

# %%
from IPython.display import clear_output

class PlotCurrentEstimate(tf.keras.callbacks.Callback):
    def __init__(self, x_valid, y_valid):
        """Keras Callback which plot current model estimate against reference target"""
        
        # convert numpy arrays into lists for plotting purposes
        self.x_valid = list(x_valid[:])
        self.y_valid = list(y_valid[:])
        self.iter=0

    def on_epoch_end(self, epoch, logs={}):
        
        temp = self.model.predict(self.x_valid, batch_size=None, verbose=False, steps=None)
        self.y_curr = list(temp[:]) # convert numpy array into list
        
        self.iter+=1
        if self.iter%10 == 0:
            clear_output(wait=True)            
            self.eplot = plt.subplot(1,1,1)
            self.eplot.clear()     
            self.eplot.scatter(self.x_valid, self.y_curr, color="blue", s=4, marker="o", label="estimate")
            self.eplot.scatter(self.x_valid, self.y_valid, color="red", s=4, marker="x", label="valid")
            self.eplot.legend()

            plt.show()

# %% [markdown]
# We will use also an EarlyStopping callback on the val_loss quantity. This will stop the training process as soon as the val_loss quantity does not improve anymore after an amount of epochs, preventing a long time of wated computation to take over without useful results.
#
# <code>keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=False)</code>
#
# Arguments:
#
# - <code>monitor</code>: quantity to be monitored.
# - <code>min_delta:</code> minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
# - <code>patience:</code> number of epochs with no improvement after which training will be stopped.
# - <code>verbose:</code> verbosity mode.
# - <code>mode:</code> one of {auto, min, max}. In min mode, training will stop when the quantity monitored has stopped decreasing; in max mode it will stop when the quantity monitored has stopped increasing; in auto mode, the direction is automatically inferred from the name of the monitored quantity.
# - <code>baseline:</code> Baseline value for the monitored quantity to reach. Training will stop if the model doesn't show improvement over the baseline.
# - <code>restore_best_weights:</code> whether to restore model weights from the epoch with the best value of the monitored quantity. If False, the model weights obtained at the last step of training are used.

# %%
plot_estimate = PlotCurrentEstimate(x_valid, y_valid)

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                  min_delta=0, patience=100, mode='auto')

model.fit(x_valid, y_valid, batch_size=32, epochs=150,
          validation_data=(x_valid, y_valid),
          callbacks=[ plot_estimate, earlystop]
          )

model.get_weights()
# Out:
# 10/10 [==============================] - 0s 14ms/sample - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# [array([[1.71564]], dtype=float32), array([1.0606877], dtype=float32)]
